# %% [markdown]
# ## This script is to keep notes on preprocessing the AnnData for MAST (XAUT1 - Blood)
#
# Last updated: 06/14/2022

# %%
import os
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_h5ad('/mnt/ibm_lg/yangjoon.kim/UC_UCSF_Multiome/XAUT1/RNA_Seq_data/merged_SCG11_14_Blood/Cellxgene/Blood MK version/22_6_13_blood_RNA_V6.h5ad')

# %%
df_obs = pd.read_csv('/mnt/ibm_lg/yangjoon.kim/UC_UCSF_Multiome/XAUT1/RNA_Seq_data/merged_SCG11_14_Blood/Cellxgene/Blood MK version/r_files/obs.csv')
df_obs
# Out:
#                  Unnamed: 0        orig.ident  nCount_RNA  nFeature_RNA  \
# 0      AAACCTGAGCGCCTTG-1_1  XAUT1-POOL-SCG11      2446.0          1087
# 1      AAACCTGAGTCCTCCT-1_1  XAUT1-POOL-SCG11       179.0           137
# 2      AAACCTGAGTGTCCAT-1_1  XAUT1-POOL-SCG11      2798.0           890
# 3      AAACCTGAGTTCGCAT-1_1  XAUT1-POOL-SCG11      2963.0          1123
# 4      AAACCTGCACATGACT-1_1  XAUT1-POOL-SCG11      2737.0          1213
# ...                     ...               ...         ...           ...
# 20125  TTTGTCAGTGACTCAT-1_4  XAUT1-POOL-SCG14      1492.0           578
# 20126  TTTGTCAGTGGCGAAT-1_4  XAUT1-POOL-SCG14      7067.0          1987
# 20127  TTTGTCAGTTATTCTC-1_4  XAUT1-POOL-SCG14      1753.0           717
# 20128  TTTGTCATCCCAAGTA-1_4  XAUT1-POOL-SCG14      2598.0          1192
# 20129  TTTGTCATCGCAGGCT-1_4  XAUT1-POOL-SCG14      3074.0          1234
#
#        NUM.SNPS  NUM.READS DROPLET.TYPE BEST.GUESS  percent.mt  percent.ribo  \
# ...

# %% [markdown]
# ## step1. Export to CSV: I used export_matrix_adata.py script in terminal to export .csv files from the AnnData.

# %%
# Run this cell or run the inside command in terminal
os.system("python export_matrix_adata.py -i /mnt/ibm_lg/yangjoon.kim/UC_UCSF_Multiome/XAUT1/RNA_Seq_data/merged_SCG11_14_Blood/Cellxgene/Blood\ MK\ version/22_6_13_blood_RNA_V6.h5ad -o /mnt/ibm_lg/yangjoon.kim/UC_UCSF_Multiome/XAUT1/RNA_Seq_data/merged_SCG11_14_Blood/Cellxgene/Blood\ MK\ version/r_files/ -c counts")

# %% [markdown]
# ## step2. Split and Process - split the data for "conditions" in a pairwise fashion
